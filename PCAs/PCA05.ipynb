# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("congress-terms.csv")
data
# Out:
#        congress chamber bioguide firstname middlename    lastname suffix  \
# 0            80   house  M000112    Joseph  Jefferson   Mansfield    NaN
# 1            80   house  D000448    Robert        Lee    Doughton    NaN
# 2            80   house  S000001    Adolph    Joachim      Sabath    NaN
# 3            80   house  E000023   Charles     Aubrey       Eaton    NaN
# 4            80   house  L000296   William        NaN       Lewis    NaN
# ...         ...     ...      ...       ...        ...         ...    ...
# 18630       113  senate  B000243       Max         S.      Baucus    NaN
# 18631       113  senate  C001099   William        NaN       Cowan    NaN
# 18632       113  senate  C001100   Jeffrey      Scott      Chiesa    NaN
# 18633       113  senate  K000148      John     Forbes       Kerry    NaN
# 18634       113  senate  L000123     Frank         R.  Lautenberg    NaN
#
#          birthday state party incumbent   termstart   age
# ...

# %%
plt.hist(data["age"])
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Starting Age of Senators")
plt.savefig("senator_hist.png")
plt.show()

# %%
under_30 = data[data["age"] < 30]
thir_to_fort = data[data["age"] >= 30]
thir_to_fort = thir_to_fort[thir_to_fort["age"] < 40]
fort_to_fift = data[data["age"] >= 40]
fort_to_fift = fort_to_fift[fort_to_fift["age"] < 50]
fift_to_sixt = data[data["age"] >= 50]
fift_to_sixt = fift_to_sixt[fift_to_sixt["age"] < 60]
sixt_to_sevt = data[data["age"] >= 60]
sixt_to_sevt = sixt_to_sevt[sixt_to_sevt["age"] < 70]
over_70 = data[data["age"] > 70]

# %%
age_data = [len(under_30), len(thir_to_fort), len(fort_to_fift), len(fift_to_sixt), len(sixt_to_sevt), len(over_70)]
labels = ["Under 30", "30-40", "40-50", "50-60", "60-70", "Over 70"]

# %%
plt.pie(age_data, labels=labels, autopct="%1.1f%%")
plt.title("Percent of Age Groups of Senators")
plt.savefig("senator_pie.png")
plt.show()
