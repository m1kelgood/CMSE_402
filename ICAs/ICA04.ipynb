# %% [markdown]
# # CMSE 402 In-Class Assignment
# ### Mikel Good
# ### 1/22/2026

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %% [markdown]
# ## Part 1

# %%
data = np.loadtxt("data_files/file1.csv", delimiter=",")

# %%
plt.plot(data[:,0], data[:,1])
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Sine Wave")
plt.savefig("sine.jpeg", dpi=400, bbox_inches="tight")

# %% [markdown]
# ## Part 2

# %%
f = h5py.File('data_files/file2.h5', 'r')

# %%
plt.plot(f["x_vals"][:], f["y_vals"][:])
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Cosine Wave")
plt.savefig("cosine.pdf")
